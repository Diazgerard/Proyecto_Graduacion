# %% [markdown]
# # Load Data to Database
#
# This notebook loads football match data and team metadata from the extracted JSON files into a PostgreSQL database.
#
# The data is organized by leagues:
# - **Data_BundesLiga**: German Bundesliga
# - **Data_La_Liga**: Spanish La Liga
# - **Data_Ligue1**: French Ligue 1
# - **Data_SerieA**: Italian Serie A
#
# ## Database Structure
#
# - **team_meta**: Stores unique team information (team_id, team_name)
# - **matches_registered**: Stores match details with all game information
# - **team_match_stats**: Stores detailed team statistics for each match

# %%
# Import required libraries
import json
import os
import psycopg2
from psycopg2.extras import execute_values
import glob
from datetime import datetime
import pandas as pd
import numpy as np


import warnings
warnings.filterwarnings("ignore")

from tqdm import tqdm

# %%
# Database Configuration
class DatabaseConfig:
    HOST = "localhost"
    PORT = 5432
    DATABASE = "4. LaLiga"  # Add your database name here
    USER = "admin"
    PASSWORD = "GadumUNITEC123"

# SQL Queries
INSERT_TEAM_QUERY = """
INSERT INTO team_meta (team_id, team_name) VALUES (%s, %s) 
ON CONFLICT (team_id) DO UPDATE SET
    team_name = EXCLUDED.team_name;
"""

INSERT_MATCH_QUERY = """
INSERT INTO matches_registered
(season_id, match_id, matchday, home_team, home_team_id, home_team_score, away_team, away_team_id, away_team_score, date_game)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s) 
ON CONFLICT (match_id) DO UPDATE SET
    season_id = EXCLUDED.season_id,
    matchday = EXCLUDED.matchday,
    home_team = EXCLUDED.home_team,
    home_team_id = EXCLUDED.home_team_id,
    home_team_score = EXCLUDED.home_team_score,
    away_team = EXCLUDED.away_team,
    away_team_id = EXCLUDED.away_team_id,
    away_team_score = EXCLUDED.away_team_score,
    date_game = EXCLUDED.date_game;
"""

# SQL Query for team match statistics - CORREGIDO SIN team_id
INSERT_TEAM_MATCH_STATS_QUERY = """
INSERT INTO team_match_stats (
    match_id, season_id, team_name, home_away,
    ttl_gls, ttl_ast, ttl_xg, ttl_xag, ttl_pk_made, ttl_pk_att, 
    ttl_yellow_cards, ttl_red_cards, ttl_gls_ag, ttl_sot_ag, ttl_saves, 
    clean_sheets, ttl_pk_att_ag, ttl_pk_saved, ttl_sh, ttl_sot, pct_sot, 
    ttl_avg_sh, ttl_gls_per_sot, ttl_gls_xg_diff, ttl_pass_cmp, ttl_pass_att, 
    pct_pass_cmp, ttl_pass_prog, ttl_key_passes, ttl_pass_opp_box, 
    ttl_cross_opp_box, ttl_pass_live, ttl_pass_dead, ttl_pass_fk, 
    ttl_through_balls, ttl_switches, ttl_crosses, ttl_pass_offside, 
    ttl_pass_blocked, ttl_throw_ins, ttl_ck, ttl_tkl, ttl_tkl_won, 
    ttl_tkl_drb, ttl_tkl_drb_att, pct_tkl_drb_suc, ttl_blocks, 
    ttl_sh_blocked, ttl_int, ttl_clearances, ttl_def_error, avg_poss, 
    ttl_touches, ttl_take_on_att, ttl_take_on_suc, ttl_carries, 
    ttl_carries_miscontrolled, ttl_carries_dispossessed, ttl_pass_rcvd, 
    ttl_pass_prog_rcvd, ttl_fls_ag, ttl_fls_for, ttl_offside, ttl_og, 
    ttl_ball_recov, ttl_air_dual_won, ttl_air_dual_lost, players_count
    ) VALUES (
    # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s,
    # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s,
    # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s,
    # %s, %s, %s, %s, %s, %s, %s, %s, %s
    ) ON CONFLICT (match_id, team_name) DO UPDATE SET
    home_away = EXCLUDED.home_away,
    ttl_gls = EXCLUDED.ttl_gls,
    ttl_ast = EXCLUDED.ttl_ast,
    ttl_xg = EXCLUDED.ttl_xg,
    ttl_xag = EXCLUDED.ttl_xag,
    ttl_pk_made = EXCLUDED.ttl_pk_made,
    ttl_pk_att = EXCLUDED.ttl_pk_att,
    ttl_yellow_cards = EXCLUDED.ttl_yellow_cards,
    ttl_red_cards = EXCLUDED.ttl_red_cards,
    ttl_gls_ag = EXCLUDED.ttl_gls_ag,
    ttl_sot_ag = EXCLUDED.ttl_sot_ag,
    ttl_saves = EXCLUDED.ttl_saves,
    clean_sheets = EXCLUDED.clean_sheets,
    ttl_pk_att_ag = EXCLUDED.ttl_pk_att_ag,
    ttl_pk_saved = EXCLUDED.ttl_pk_saved,
    ttl_sh = EXCLUDED.ttl_sh,
    ttl_sot = EXCLUDED.ttl_sot,
    pct_sot = EXCLUDED.pct_sot,
    ttl_avg_sh = EXCLUDED.ttl_avg_sh,
    ttl_gls_per_sot = EXCLUDED.ttl_gls_per_sot,
    ttl_gls_xg_diff = EXCLUDED.ttl_gls_xg_diff,
    ttl_pass_cmp = EXCLUDED.ttl_pass_cmp,
    ttl_pass_att = EXCLUDED.ttl_pass_att,
    pct_pass_cmp = EXCLUDED.pct_pass_cmp,
    ttl_pass_prog = EXCLUDED.ttl_pass_prog,
    ttl_key_passes = EXCLUDED.ttl_key_passes,
    ttl_pass_opp_box = EXCLUDED.ttl_pass_opp_box,
    ttl_cross_opp_box = EXCLUDED.ttl_cross_opp_box,
    ttl_pass_live = EXCLUDED.ttl_pass_live,
    ttl_pass_dead = EXCLUDED.ttl_pass_dead,
    ttl_pass_fk = EXCLUDED.ttl_pass_fk,
    ttl_through_balls = EXCLUDED.ttl_through_balls,
    ttl_switches = EXCLUDED.ttl_switches,
    ttl_crosses = EXCLUDED.ttl_crosses,
    ttl_pass_offside = EXCLUDED.ttl_pass_offside,
    ttl_pass_blocked = EXCLUDED.ttl_pass_blocked,
    ttl_throw_ins = EXCLUDED.ttl_throw_ins,
    ttl_ck = EXCLUDED.ttl_ck,
    ttl_tkl = EXCLUDED.ttl_tkl,
    ttl_tkl_won = EXCLUDED.ttl_tkl_won,
    ttl_tkl_drb = EXCLUDED.ttl_tkl_drb,
    ttl_tkl_drb_att = EXCLUDED.ttl_tkl_drb_att,
    pct_tkl_drb_suc = EXCLUDED.pct_tkl_drb_suc,
    ttl_blocks = EXCLUDED.ttl_blocks,
    ttl_sh_blocked = EXCLUDED.ttl_sh_blocked,
    ttl_int = EXCLUDED.ttl_int,
    ttl_clearances = EXCLUDED.ttl_clearances,
    ttl_def_error = EXCLUDED.ttl_def_error,
    avg_poss = EXCLUDED.avg_poss,
    ttl_touches = EXCLUDED.ttl_touches,
    ttl_take_on_att = EXCLUDED.ttl_take_on_att,
    ttl_take_on_suc = EXCLUDED.ttl_take_on_suc,
    ttl_carries = EXCLUDED.ttl_carries,
    ttl_carries_miscontrolled = EXCLUDED.ttl_carries_miscontrolled,
    ttl_carries_dispossessed = EXCLUDED.ttl_carries_dispossessed,
    ttl_pass_rcvd = EXCLUDED.ttl_pass_rcvd,
    ttl_pass_prog_rcvd = EXCLUDED.ttl_pass_prog_rcvd,
    ttl_fls_ag = EXCLUDED.ttl_fls_ag,
    ttl_fls_for = EXCLUDED.ttl_fls_for,
    ttl_offside = EXCLUDED.ttl_offside,
    ttl_og = EXCLUDED.ttl_og,
    ttl_ball_recov = EXCLUDED.ttl_ball_recov,
    ttl_air_dual_won = EXCLUDED.ttl_air_dual_won,
    ttl_air_dual_lost = EXCLUDED.ttl_air_dual_lost,
    players_count = EXCLUDED.players_count;
"""

# %%
# Conexión a la base de datos PostgreSQL
def connect_to_database():
    try:
        conn = psycopg2.connect(
            host=DatabaseConfig.HOST,
            port=DatabaseConfig.PORT,
            dbname=DatabaseConfig.DATABASE,
            user=DatabaseConfig.USER,
            password=DatabaseConfig.PASSWORD
        )
        return conn
    except Exception as e:
        print(f"Error connecting to database: {e}")
        return None

# %%
# Create Database Tables
def create_tables():
    """Create the required database tables if they don't exist"""
    conn = connect_to_database()
    if not conn:
        print("No se pudo conectar a la base de datos")
        return
    try:
        cursor = conn.cursor()
        CREATE_TEAM_META_TABLE = """
        CREATE TABLE IF NOT EXISTS team_meta (
            team_id VARCHAR(50) PRIMARY KEY,
            team_name VARCHAR(100) NOT NULL,
            created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            updated_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
        );
        """
        CREATE_MATCHES_TABLE = """
        CREATE TABLE IF NOT EXISTS matches_registered (
            match_id VARCHAR(50) PRIMARY KEY,
            season_id VARCHAR(20) NOT NULL,
            matchday INTEGER NOT NULL,
            home_team VARCHAR(100) NOT NULL,
            home_team_id VARCHAR(50) NOT NULL,
            home_team_score INTEGER NOT NULL,
            away_team VARCHAR(100) NOT NULL,
            away_team_id VARCHAR(50) NOT NULL,
            away_team_score INTEGER NOT NULL,
            date_game TIMESTAMP NOT NULL,
            created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            updated_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            FOREIGN KEY (home_team_id) REFERENCES team_meta(team_id),
            FOREIGN KEY (away_team_id) REFERENCES team_meta(team_id)
        );
        """
        CREATE_TEAM_MATCH_STATS_TABLE = """
        CREATE TABLE IF NOT EXISTS team_match_stats (
            match_id VARCHAR(50) NOT NULL,
            season_id VARCHAR(20) NOT NULL,
            team_name VARCHAR(100) NOT NULL,
            home_away VARCHAR(10) NOT NULL,
            ttl_gls NUMERIC,
            ttl_ast NUMERIC,
            ttl_xg NUMERIC,
            ttl_xag NUMERIC,
            ttl_pk_made NUMERIC,
            ttl_pk_att NUMERIC,
            ttl_yellow_cards NUMERIC,
            ttl_red_cards NUMERIC,
            ttl_gls_ag NUMERIC,
            ttl_sot_ag NUMERIC,
            ttl_saves NUMERIC,
            clean_sheets NUMERIC,
            ttl_pk_att_ag NUMERIC,
            ttl_pk_saved NUMERIC,
            ttl_sh NUMERIC,
            ttl_sot NUMERIC,
            pct_sot NUMERIC,
            ttl_avg_sh NUMERIC,
            ttl_gls_per_sot NUMERIC,
            ttl_gls_xg_diff NUMERIC,
            ttl_pass_cmp NUMERIC,
            ttl_pass_att NUMERIC,
            pct_pass_cmp NUMERIC,
            ttl_pass_prog NUMERIC,
            ttl_key_passes NUMERIC,
            ttl_pass_opp_box NUMERIC,
            ttl_cross_opp_box NUMERIC,
            ttl_pass_live NUMERIC,
            ttl_pass_dead NUMERIC,
            ttl_pass_fk NUMERIC,
            ttl_through_balls NUMERIC,
            ttl_switches NUMERIC,
            ttl_crosses NUMERIC,
            ttl_pass_offside NUMERIC,
            ttl_pass_blocked NUMERIC,
            ttl_throw_ins NUMERIC,
            ttl_ck NUMERIC,
            ttl_tkl NUMERIC,
            ttl_tkl_won NUMERIC,
            ttl_tkl_drb NUMERIC,
            ttl_tkl_drb_att NUMERIC,
            pct_tkl_drb_suc NUMERIC,
            ttl_blocks NUMERIC,
            ttl_sh_blocked NUMERIC,
            ttl_int NUMERIC,
            ttl_clearances NUMERIC,
            ttl_def_error NUMERIC,
            avg_poss NUMERIC,
            ttl_touches NUMERIC,
            ttl_take_on_att NUMERIC,
            ttl_take_on_suc NUMERIC,
            ttl_carries NUMERIC,
            ttl_carries_miscontrolled NUMERIC,
            ttl_carries_dispossessed NUMERIC,
            ttl_pass_rcvd NUMERIC,
            ttl_pass_prog_rcvd NUMERIC,
            ttl_fls_ag NUMERIC,
            ttl_fls_for NUMERIC,
            ttl_offside NUMERIC,
            ttl_og NUMERIC,
            ttl_ball_recov NUMERIC,
            ttl_air_dual_won NUMERIC,
            ttl_air_dual_lost NUMERIC,
            players_count INTEGER,
            created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            updated_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            UNIQUE (match_id, team_name),
            FOREIGN KEY (match_id) REFERENCES matches_registered(match_id)
        );
        """
        cursor.execute(CREATE_TEAM_META_TABLE)
        cursor.execute(CREATE_MATCHES_TABLE)
        cursor.execute(CREATE_TEAM_MATCH_STATS_TABLE)
        conn.commit()
        print("Tablas creadas correctamente.")
    except Exception as e:
        print(f"Error creando tablas: {e}")
    finally:
        cursor.close()
        conn.close()

# %%
# Ejecutar la creación de tablas
create_tables()
# Out:
# Tablas creadas correctamente.

# %%
def clean_value(v):
    try:
        # Convierte a float o int si es posible
        val = float(v)
        return int(val)  # PostgreSQL suele usar integer
    except (TypeError, ValueError):
        return 0


# Función para limpiar team_id
def clean_team_id(v):
    return v if v is not None else 0

def calculate_missing(stats):
    """Calcula métricas faltantes si se pueden derivar."""
    
    # % tiros a puerta
    if stats.get("pct_sot") is None:
        sh = stats.get("ttl_sh")
        sot = stats.get("ttl_sot")
        if sh and sh > 0 and sot is not None:
            stats["pct_sot"] = (sot / sh) * 100
    
    # % pases completados
    if stats.get("pct_pass_cmp") is None:
        cmp_ = stats.get("ttl_pass_cmp")
        att_ = stats.get("ttl_pass_att")
        if cmp_ and att_ and att_ > 0:
            stats["pct_pass_cmp"] = (cmp_ / att_) * 100

    return stats



def insert_json_match(json_data, cursor):
    """
    Inserta team_meta, matches_registered y team_match_stats de un JSON.
    """

    # ------------------------------------------------------
    # INSERT 1: team_meta (home y away)
    # ------------------------------------------------------
    for t in json_data["teams"]:
        cursor.execute("""
            INSERT INTO team_meta (team_id, team_name)
            VALUES (%s, %s)
            ON CONFLICT (team_id) DO UPDATE
            SET team_name = EXCLUDED.team_name,
                updated_at = CURRENT_TIMESTAMP;
        """, (t["team_id"], t["team_name"]))

    # ------------------------------------------------------
    # INSERT 2: matches_registered
    # ------------------------------------------------------
    m = json_data["match_info"]

    cursor.execute("""
        INSERT INTO matches_registered (
            match_id, season_id, matchday,
            home_team, home_team_id, home_team_score,
            away_team, away_team_id, away_team_score,
            date_game
        )
        VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
        ON CONFLICT (match_id) DO UPDATE
        SET updated_at = CURRENT_TIMESTAMP;
    """, (
        m["match_id"], m["season_id"], m["matchday"],
        m["home_team"], m["home_team_id"], m["home_team_score"],
        m["away_team"], m["away_team_id"], m["away_team_score"],
        m["date_game"]
    ))

    # ------------------------------------------------------
    # INSERT 3: team_match_stats
    # ------------------------------------------------------

    # Orden EXACTO segun tu tabla
    db_fields = [
        "match_id", "season_id", "team_name", "home_away",
        "ttl_gls", "ttl_ast", "ttl_xg", "ttl_xag",
        "ttl_pk_made", "ttl_pk_att",
        "ttl_yellow_cards", "ttl_red_cards",
        "ttl_gls_ag", "ttl_sot_ag", "ttl_saves", "clean_sheets",
        "ttl_pk_att_ag", "ttl_pk_saved",
        "ttl_sh", "ttl_sot", "pct_sot",
        "ttl_avg_sh", "ttl_gls_per_sot", "ttl_gls_xg_diff",
        "ttl_pass_cmp", "ttl_pass_att", "pct_pass_cmp",
        "ttl_pass_prog", "ttl_key_passes",
        "ttl_pass_opp_box", "ttl_cross_opp_box",
        "ttl_pass_live", "ttl_pass_dead", "ttl_pass_fk",
        "ttl_through_balls", "ttl_switches", "ttl_crosses",
        "ttl_pass_offside", "ttl_pass_blocked", "ttl_throw_ins", "ttl_ck",
        "ttl_tkl", "ttl_tkl_won",
        "ttl_tkl_drb", "ttl_tkl_drb_att", "pct_tkl_drb_suc",
        "ttl_blocks", "ttl_sh_blocked", "ttl_int", "ttl_clearances", "ttl_def_error",
        "avg_poss",
        "ttl_touches", "ttl_take_on_att", "ttl_take_on_suc",
        "ttl_carries", "ttl_carries_miscontrolled", "ttl_carries_dispossessed",
        "ttl_pass_rcvd", "ttl_pass_prog_rcvd",
        "ttl_fls_ag", "ttl_fls_for",
        "ttl_offside", "ttl_og", "ttl_ball_recov",
        "ttl_air_dual_won", "ttl_air_dual_lost",
        "players_count"
    ]

    for t in json_data["teams"]:
        
        # COPIAR stats crudos
        stats = {k: t.get(k) for k in db_fields if k in t or k in ["match_id","season_id","team_name","home_away"]}

        # LIMPIEZA
        for key in stats:
            if key not in ["match_id", "team_name", "home_away", "season_id"]:
                stats[key] = clean_value(stats[key])

        # CALCULAR MÉTRICAS FALTANTES
        stats = calculate_missing(stats)

        # RELLENAR CAMPOS FALTANTES COMO NULL
        for f in db_fields:
            if f not in stats:
                stats[f] = None

        # ARMAR LISTA DE VALORES EN ORDEN CORRECTO
        values = [stats[f] for f in db_fields]

        # INSERT FINAL
        cursor.execute(f"""
            INSERT INTO team_match_stats ({",".join(db_fields)})
            VALUES ({",".join(["%s"] * len(db_fields))})
            ON CONFLICT (match_id, team_name)
            DO UPDATE SET updated_at = CURRENT_TIMESTAMP;
        """, values)

# %% [markdown]
# ## Data Loading Process
#
# **⚠️ IMPORTANT: Make sure to set the DATABASE name in the DatabaseConfig class above before running!**
#
# The following sections will process each league's data and upload it to the database.

# %% [markdown]
# ### 🇪🇸 La Liga (Spanish Primera División)

# %%
import glob
import json
import os

# Carpeta principal de La Liga
data_path = "Data_Extracted"
laliga_folder = os.path.join(data_path, "Data_La_Liga")

# Lista para almacenar todos los partidos
laliga_stats = []

# Contadores para el resumen
total_files = 0
loaded_files = 0
json_errors = []
missing_match_info = []

for season_folder in sorted(os.listdir(laliga_folder)):
    matches_folder = os.path.join(laliga_folder, season_folder, "Matches", "Matches_Stats")
    if os.path.exists(matches_folder):
        # Buscar todos los JSON recursivamente
        files = glob.glob(os.path.join(matches_folder, "**", "*.json"), recursive=True)
        print(f"{season_folder}: {len(files)} archivos encontrados")
        total_files += len(files)

        for file in files:
            try:
                with open(file, "r", encoding="utf-8") as f:
                    match_data = json.load(f)
                
                # Si no existe 'match_info', crear uno mínimo con match_id
                if "match_info" not in match_data:
                    match_data["match_info"] = {
                        "match_id": match_data.get("match_id", None),
                        "season_id": season_folder,
                        "matchday": None,
                        "home_team": None,
                        "home_team_id": None,
                        "home_team_score": 0,
                        "away_team": None,
                        "away_team_id": None,
                        "away_team_score": 0,
                        "date_game": None
                    }
                    missing_match_info.append(file)

                laliga_stats.append(match_data)
                loaded_files += 1
            except Exception as e:
                json_errors.append((file, str(e)))

    else:
        print(f"{season_folder}: carpeta {matches_folder} NO existe")

# Resumen de carga
print("\nResumen de carga:")
print(f"Archivos JSON totales encontrados: {total_files}")
print(f"Archivos cargados correctamente: {loaded_files}")
print(f"Archivos con error de JSON: {len(json_errors)}")
print(f"Archivos sin 'match_info': {len(missing_match_info)}\n")

if json_errors:
    print("Archivos con error JSON:")
    for f, e in json_errors:
        print(f"  {f}: {e}")

if missing_match_info:
    print("Archivos sin 'match_info':")
    for f in missing_match_info:
        print(f"  {f}")

print(f"\nTotal partidos cargados en laliga_stats: {len(laliga_stats)}")
# Out:
# 2017-2018: 369 archivos encontrados
# 2018-2019: 364 archivos encontrados
# 2019-2020: 306 archivos encontrados
# 2020-2021: 188 archivos encontrados
# 2021-2022: carpeta Data_Extracted\Data_La_Liga\2021-2022\Matches\Matches_Stats NO existe
# 2022-2023: 175 archivos encontrados
# 2023-2024: 380 archivos encontrados
# 2024-2025: 380 archivos encontrados
#
# Resumen de carga:
# Archivos JSON totales encontrados: 2162
# Archivos cargados correctamente: 2162
# Archivos con error de JSON: 0
# Archivos sin 'match_info': 380
#
# Archivos sin 'match_info':
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\00bca7c4_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\01197df1_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\018fa1b4_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\02169120_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\028b10dc_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\02bfae4e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\036a4747_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\041d6702_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\0425fc2d_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\04b6223f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\050fe7c2_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\05130dc3_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\0580ab96_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\05c5e52d_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\0688f714_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\069145b6_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\07598e53_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\07f29baa_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\08e02efc_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\0a6de3d3_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\0b2c987f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\0b823038_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\0bb2b5ef_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\0c8db441_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\0d54805a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\0df1f571_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\0edcec5d_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\10db0915_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\11192bf0_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\117692e2_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\1182bc6e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\11bcd802_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\124ad510_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\12536c9f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\12ce04dc_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\131899cd_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\138c629e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\14179de8_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\14a28e57_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\15ceb2e9_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\15e84040_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\160a9af7_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\17125161_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\1716ac24_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\173a87bb_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\1838bcd7_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\18dc29a4_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\1971e698_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\19ca64ed_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\1c29483b_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\1ca7012a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\1e429e52_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\1fe130a9_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\2053d836_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\20bdd334_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\2307f9b9_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\231f83bc_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\2367dade_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\2395eb39_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\243cb41c_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\2450ca46_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\24f9975b_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\25a5934a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\26d75d6d_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\2702096e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\27871b65_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\2839ad16_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\28b22659_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\28cd11c2_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\291cfd49_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\2a59dd47_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\2b4789d5_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\2c94bff7_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\2f5ca11f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\30fa33ba_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\32bb9a67_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\336bf51e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\3438a56b_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\34a6798a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\3537bd55_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\36e23ef5_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\3736c3d4_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\377a6000_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\37cd2f6c_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\37e0a484_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\382d5e03_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\384225d1_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\3865f1d2_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\38d25c90_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\39cd05e4_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\39db2a13_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\3aa5024f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\3c487349_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\3c660029_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\3c8fe9de_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\3ecbf46e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\3ed1b8ff_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\3ee384b4_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\3f2f6c96_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\409ec366_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\4106e75f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\4223fbb4_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\4303125c_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\43c02c2b_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\43d7418a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\442a63df_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\442c5b57_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\4525bc01_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\454dc8c7_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\45dbbb22_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\45dc71b5_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\45f486b1_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\46815a4a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\46e117e0_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\477327f9_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\49cf201f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\4b093821_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\4c283fa8_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\4c7eab6f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\4d0c9845_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\4f2bd132_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\4fb3dc98_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\50a17164_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\50b976fc_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\50bf3afb_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\50cdc0c9_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\5160bd9d_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\521b1f26_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\535ec951_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\539f05d4_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\54538ff7_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\54fa5083_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\55b7dfaa_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\5632f505_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\570273ee_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\572463cb_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\57baf278_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\57bc3e19_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\57eb3b4f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\585ef159_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\591dbf90_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\59703f58_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\597f83c1_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\59db0a32_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\5a140caa_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\5ae33594_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\5bf2e4ce_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\5dbf000f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\5dd33e2b_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\5ea3b789_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\5f73bf47_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\5f83ac85_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\6049a447_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\606774d3_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\60a46aeb_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\60c208f0_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\613f75be_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\618988b7_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\62c1d5cc_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\62f87a02_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\6358b738_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\64cac73e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\650b3ea7_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\652b900c_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\6566ae8c_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\65afea5b_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\66b19e25_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\6996fe18_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\6a475fea_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\6b0f1761_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\6b455e82_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\6b5549c2_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\6c84aa28_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\6ced9ec5_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\6dfa7503_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\6e3da6f1_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\6e84530a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\6e8b4c78_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\6ebd56ef_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\6f0fac43_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\71669703_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\71df1d23_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\722b1ca2_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\72aa5092_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\738f8f85_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\75d8fa7a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\75fab2fb_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\7652232d_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\766b10ee_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\776298df_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\77dda45d_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\7925ae38_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\79bd89e0_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\79c38937_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\7aa26780_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\7ba8b655_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\7bfbe87f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\7c1a412b_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\7c70cc19_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\7d25dd93_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\7d98a38f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\7e4ab762_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\7f56d98f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\818dc175_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\81da0725_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\81dad4eb_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\82605913_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\82c58306_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\843a0b94_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\84f347ad_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\858bd9c5_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\85f339a3_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\86447b37_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\864a0fb8_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\87b1fc3e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\87bc9bba_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\887132d0_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\89b88d0b_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\89c7a794_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\8a068dcb_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\8a159d42_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\8c459ad5_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\8cc12868_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\8dcf829f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\8ddf3820_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\8eba22e2_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\8f767bea_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\8f9e0139_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\90b5ee8e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\90cf8629_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\9289e6ed_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\94fe3705_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\95447cec_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\988deece_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\9b519ed0_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\9bb16911_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\9bf91e35_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\9c8b0304_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\9dbc3e14_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\9efb7811_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\a008668e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\a0128620_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\a0c7186e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\a11727e1_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\a1ad64bb_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\a214487d_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\a449c18e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\a46e38e7_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\a5448163_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\a5ffdc50_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\a71ce7d1_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ab452039_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\abe69737_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ac04a5d2_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ac3f8e9a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ac6535dc_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\acc2bc45_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\aef7cc8d_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\af7b751a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\af815599_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\af94853a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\aff51fb4_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\b0b640d3_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\b14bf95b_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\b1f96209_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\b21dd238_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\b299fca9_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\b418c449_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\b53b2cc8_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\b5605cb6_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\b724ff67_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\b757e16f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\b7bb2f84_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\b839d4ce_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\b85ff6cf_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\b955d331_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\b979258f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\b992fee4_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\b9c25e18_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ba5dd68e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\bb8e8b39_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\bc2261f6_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\bc459f49_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\bd9c5fd6_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\be0ab7a4_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\be12049b_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\bf02d20b_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\bfba2fd7_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\c38bd41c_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\c667c7ca_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\c6b7a6e0_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\c6c0a3d3_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\c745f73f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\c7505bdc_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\c89b7f67_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\c8f36a4b_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\c9404de2_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\c9bdc26a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\cb080ed5_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\cb8011f0_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\cc85a3d4_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\cdb994ab_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\cddbefd1_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\cde582d4_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ce67853a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\d0f5d736_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\d2722540_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\d2dd62e7_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\d32fffe0_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\d3f13884_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\d554e8b9_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\d59e698a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\d5c58cc9_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\d67421c6_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\d8d672fa_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\db2637b7_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\dc8dc26b_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\de9887c1_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\defd20c7_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\dfd588e7_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e0d46d97_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e11566fd_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e176243c_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e1cfa735_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e1e5325c_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e2ee9d3d_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e33c8281_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e42061f0_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e55b978c_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e593cd07_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e5de943f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e69b0060_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e6b730a8_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e6bc2844_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e7540b3e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e79d506b_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e7bdcc56_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e826cf9e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e88639fb_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e9c90680_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\e9fe833a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ebe2bfbd_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ec18b3aa_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ec6e214e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ecd47b8a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ed775615_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ed820dc1_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\edd88e45_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ee8fb4af_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ef04c85d_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ef8bf64a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\f079fabc_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\f0be0a37_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\f13e982e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\f166ffc9_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\f17ca419_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\f1804d9c_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\f1dd2f9a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\f1e4f58c_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\f2459bac_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\f32a65e4_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\f5dbb50d_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\f6040fa5_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\f7ee4708_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\f880625e_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\f8b3c447_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\f8fc00c7_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\fa0d939a_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\fa808cc1_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\fae6d2fd_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\fb5d09d6_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\fbad97f4_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\fc79d1e0_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\fce1658d_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\fd632e2f_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\fdd30e13_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\fe96c24b_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ff92ae47_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ffb1fa1d_stats.json
#   Data_Extracted\Data_La_Liga\2024-2025\Matches\Matches_Stats\ffc4972d_stats.json
#
# Total partidos cargados en laliga_stats: 2162

# %%
# Conectar a la base de datos
conn = connect_to_database()
if not conn:
    raise Exception("No se pudo conectar a la base de datos")

teams_data = []

# Recorremos todos los partidos y sus equipos
for match in laliga_stats:
    for t in match["teams"]:
        team_id = t.get("team_id")
        team_name = t.get("team_name")
        if team_id and team_name:
            teams_data.append((team_id, team_name))

# Eliminar duplicados por team_id
teams_data = list({t[0]: t for t in teams_data}.values())

# Insertar equipos
try:
    cursor = conn.cursor()
    cursor.executemany(INSERT_TEAM_QUERY, teams_data)
    conn.commit()
    print(f"Insertados {len(teams_data)} equipos en team_meta")
except Exception as e:
    print(f"Error insertando equipos: {e}")
    conn.rollback()
finally:
    cursor.close()
    conn.close()
# Out:
# Insertados 124 equipos en team_meta

# %%
# Conectar a la base de datos
conn = connect_to_database()
if not conn:
    raise Exception("No se pudo conectar a la base de datos")

matches_data = []
ignored_count = 0  # Contador de partidos ignorados

for match in laliga_stats:
    info = match.get("match_info", None)

    if not info:
        ignored_count += 1
        continue  # Ignoramos partidos sin match_info

    # Extraemos datos seguros de match_info
    season_id = info.get("season_id", "Unknown")
    match_id = info.get("match_id", "Unknown")
    matchday = info.get("matchday", 0) or 0
    home_team = info.get("home_team", "Unknown")
    home_team_id = info.get("home_team_id")  # No reemplazar por 0, para no violar FK
    home_team_score = info.get("home_team_score", 0) or 0
    away_team = info.get("away_team", "Unknown")
    away_team_id = info.get("away_team_id")  # No reemplazar por 0, para no violar FK
    away_team_score = info.get("away_team_score", 0) or 0
    date_game = info.get("date_game", "1970-01-01")

    # Solo agregar si los campos obligatorios existen para respetar FK y NOT NULL
    if home_team_id is not None and away_team_id is not None:
        matches_data.append((
            season_id, match_id, matchday,
            home_team, home_team_id, home_team_score,
            away_team, away_team_id, away_team_score,
            date_game
        ))
    else:
        ignored_count += 1  # Ignoramos si faltan IDs de equipo

try:
    cursor = conn.cursor()
    cursor.executemany(INSERT_MATCH_QUERY, matches_data)
    conn.commit()
    print(f"Insertados {len(matches_data)} partidos en matches_registered")
    print(f"Ignorados {ignored_count} partidos sin match_info o con datos incompletos")
except Exception as e:
    print(f"Error insertando partidos: {e}")
    conn.rollback()
finally:
    cursor.close()
    conn.close()
# Out:
# Insertados 1782 partidos en matches_registered
# Ignorados 380 partidos sin match_info o con datos incompletos

# %%
# Cargar datos de La Liga a la base de datos
conn = connect_to_database()
if not conn:
    raise Exception("No se pudo conectar a la base de datos")

cursor = conn.cursor()

def clean_db_value(v):
    if v is None or v == "NA":
        return 0
    try:
        val = float(v)
        return int(val)
    except (TypeError, ValueError):
        return 0

inserted_matches = 0
inserted_stats = 0
for match in laliga_stats:
    # Insertar equipos (ya se hizo en celda anterior, pero por seguridad)
    for t in match["teams"]:
        team_id = t.get("team_id")
        team_name = t.get("team_name")
        if team_id and team_name:
            cursor.execute(INSERT_TEAM_QUERY, (team_id, team_name))

    # Insertar partido
    m = match.get("match_info", {})
    match_id = m.get("match_id")
    season_id = m.get("season_id", "Unknown")
    matchday = clean_db_value(m.get("matchday", 0))
    home_team = m.get("home_team", "Unknown")
    home_team_id = m.get("home_team_id")
    home_team_score = clean_db_value(m.get("home_team_score", 0))
    away_team = m.get("away_team", "Unknown")
    away_team_id = m.get("away_team_id")
    away_team_score = clean_db_value(m.get("away_team_score", 0))
    date_game = m.get("date_game", "1970-01-01")

    if home_team_id is not None and away_team_id is not None and match_id is not None:
        cursor.execute(INSERT_MATCH_QUERY, (
            season_id, match_id, matchday,
            home_team, home_team_id, home_team_score,
            away_team, away_team_id, away_team_score,
            date_game
        ))
        inserted_matches += 1

    # Insertar estadísticas de equipos por partido
    db_fields = [
        "match_id", "season_id", "team_name", "home_away",
        "ttl_gls", "ttl_ast", "ttl_xg", "ttl_xag",
        "ttl_pk_made", "ttl_pk_att",
        "ttl_yellow_cards", "ttl_red_cards",
        "ttl_gls_ag", "ttl_sot_ag", "ttl_saves", "clean_sheets",
        "ttl_pk_att_ag", "ttl_pk_saved",
        "ttl_sh", "ttl_sot", "pct_sot",
        "ttl_avg_sh", "ttl_gls_per_sot", "ttl_gls_xg_diff",
        "ttl_pass_cmp", "ttl_pass_att", "pct_pass_cmp",
        "ttl_pass_prog", "ttl_key_passes",
        "ttl_pass_opp_box", "ttl_cross_opp_box",
        "ttl_pass_live", "ttl_pass_dead", "ttl_pass_fk",
        "ttl_through_balls", "ttl_switches", "ttl_crosses",
        "ttl_pass_offside", "ttl_pass_blocked", "ttl_throw_ins", "ttl_ck",
        "ttl_tkl", "ttl_tkl_won",
        "ttl_tkl_drb", "ttl_tkl_drb_att", "pct_tkl_drb_suc",
        "ttl_blocks", "ttl_sh_blocked", "ttl_int", "ttl_clearances", "ttl_def_error",
        "avg_poss",
        "ttl_touches", "ttl_take_on_att", "ttl_take_on_suc",
        "ttl_carries", "ttl_carries_miscontrolled", "ttl_carries_dispossessed",
        "ttl_pass_rcvd", "ttl_pass_prog_rcvd",
        "ttl_fls_ag", "ttl_fls_for",
        "ttl_offside", "ttl_og", "ttl_ball_recov",
        "ttl_air_dual_won", "ttl_air_dual_lost",
        "players_count"
    ]

    for t in match["teams"]:
        stats = {k: t.get(k) for k in db_fields}
        # Limpiar valores
        for key in stats:
            if key not in ["match_id", "team_name", "home_away", "season_id"]:
                stats[key] = clean_db_value(stats[key])
        # Rellenar campos faltantes
        for f in db_fields:
            if stats[f] is None:
                stats[f] = 0
        values = [stats[f] for f in db_fields]
        cursor.execute(f"""
            INSERT INTO team_match_stats ({','.join(db_fields)})
            VALUES ({','.join(['%s'] * len(db_fields))})
            ON CONFLICT (match_id, team_name)
            DO UPDATE SET updated_at = CURRENT_TIMESTAMP;
        """, values)
        inserted_stats += 1

conn.commit()
print(f"Partidos insertados: {inserted_matches}")
print(f"Estadísticas insertadas: {inserted_stats}")

cursor.close()
conn.close()
# Out:
# Partidos insertados: 1782
# Estadísticas insertadas: 4320

# %% [markdown]
# ### 🇩🇪 Bundesliga (German First Division)

# %%
# Load Bundesliga data
bundesliga_folder = os.path.join(data_path, "Data_BundesLiga")

bundesliga_matches, bundesliga_teams, bundesliga_stats = process_league_data("Bundesliga", bundesliga_folder)

# %% [markdown]
# ### 🇮🇹 Serie A (Italian First Division)

# %%
# Load Serie A data
seriea_folder = os.path.join(data_path, "Data_SerieA")

seriea_matches, seriea_teams, seriea_stats = process_league_data("Serie A", seriea_folder)

# %% [markdown]
# ### 🇫🇷 Ligue 1 (French First Division)

# %%
# Load Ligue 1 data
ligue1_folder = os.path.join(data_path, "Data_Ligue1")

ligue1_matches, ligue1_teams, ligue1_stats = process_league_data("Ligue 1", ligue1_folder)
